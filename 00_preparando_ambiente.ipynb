-- %%
%sql

CREATE SCHEMA IF NOT EXISTS workspace.landing
  COMMENT 'Landing Zone - dados brutos CSV/JSON';

CREATE VOLUME IF NOT EXISTS workspace.landing.dados
  COMMENT 'Volume para arquivos brutos da origem';

CREATE SCHEMA IF NOT EXISTS workspace.bronze
  COMMENT 'Camada Bronze - Delta Lake bruto';

CREATE SCHEMA IF NOT EXISTS workspace.silver
  COMMENT 'Camada Silver - Delta Lake tratado';

CREATE SCHEMA IF NOT EXISTS workspace.gold
  COMMENT 'Camada Gold - Modelagem Dimensional';

-- %%
%sql
SHOW SCHEMAS IN workspace;
